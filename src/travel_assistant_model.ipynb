# %%
import pandas as pd
import data_utility
from textblob import TextBlob  # For sentiment analysis

# %%
hotel_reviews_df = data_utility.get_hotel_reviews()
hotel_reviews_df
# Out:
# /Users/Ajay/Development/AIBootcamp_Git/project3-group3-travel-assistant/src/data_utility.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   hotel_reviews_df = pd.concat(h_dfs).reset_index(drop=True)
#                          id             dateAdded           dateUpdated  \
# 0      AVwcwF98IN2L1WUfofTr  2016-09-08T04:51:06Z  2019-04-01T06:07:08Z
# 1      AVwcuBhNkufWRAb5ySF1  2016-04-08T12:34:14Z  2019-04-01T06:03:50Z
# 2      AVwemLkAkufWRAb5EaiN  2016-05-16T23:08:33Z  2019-04-01T06:01:53Z
# 3      AVwemLkAkufWRAb5EaiN  2016-05-16T23:08:33Z  2019-04-01T06:01:53Z
# 4      AVwdRR77_7pvs4fz4Gxu  2016-07-18T19:37:51Z  2019-04-01T05:15:49Z
# ...                     ...                   ...                   ...
# 19782  AVwd4TMv_7pvs4fz-Ers  2016-03-24T11:44:15Z  2018-01-01T00:00:46Z
# 19783  AVwdRp4DIN2L1WUfuGZZ  2015-10-26T23:03:02Z  2018-01-01T00:00:44Z
# 19784  AVwd1TbkByjofQCxs6FH  2016-06-11T03:12:23Z  2018-01-01T00:00:44Z
# 19785  AVwdHbizIN2L1WUfsXto  2016-12-13T03:44:36Z  2018-01-01T00:00:43Z
# 19786  AVwddMfdIN2L1WUfwAue  2016-06-22T19:07:21Z  2018-01-01T00:00:43Z
#
#                     address  \
# 0      117 Sleepy Valley Rd
# 1         425 Sunny Rest Dr
# 2           4026 Jackpot Rd
# 3           4026 Jackpot Rd
# 4              281 State St
# ...                     ...
# 19782      215 S Pacific St
# 19783          669 Route 6a
# 19784    702 W Appleway Ave
# 19785   2295 N Highland Ave
# 19786     3811 Minnesota Dr
#
#                                               categories  \
# 0      Bed Breakfasts,Bed & Breakfasts,Hotels Motels,...
# 1                            Resorts,Hotels Motels,Hotel
# 2                     Hotels,Lodging,Hotels Motels,Hotel
# 3                     Hotels,Lodging,Hotels Motels,Hotel
# 4                     Bed Breakfasts,Hotels Motels,Hotel
# ...                                                  ...
# 19782                        Hotel,Hotels,Lodging,Motels
# 19783                                       Hotel,Hotels
# 19784  Hotel,Hotel, Motel, and Building,Hotels,Lodgin...
# 19785  Hotel,Hotels Motels,Budget Hotels,Hotels & Motels
# 19786      Hotel,Motels,Lodging,Hotels,Hotels and Motels
#
#                    primaryCategories            city country  \
# 0      Accommodation & Food Services         Warwick      US
# 1      Accommodation & Food Services       Palmerton      US
# 2      Accommodation & Food Services      Grove City      US
# 3      Accommodation & Food Services      Grove City      US
# 4      Accommodation & Food Services          Albany      US
# ...                              ...             ...     ...
# 19782  Accommodation & Food Services  Rockaway Beach      US
# 19783  Accommodation & Food Services   East Sandwich      US
# 19784  Accommodation & Food Services   Coeur d'Alene      US
# 19785  Accommodation & Food Services         Jackson      US
# 19786  Accommodation & Food Services       Anchorage      US
#
#                                                 keys  latitude  ...  \
# 0          us/ny/warwick/117sleepyvalleyrd/666874344  41.28030  ...
# 1          us/pa/palmerton/425sunnyrestdr/-911692460  40.82360  ...
# 2           us/oh/grovecity/4026jackpotrd/-295222033  39.87970  ...
# 3           us/oh/grovecity/4026jackpotrd/-295222033  39.87970  ...
# 4                us/ny/albany/281statest/-1845507403  42.65450  ...
# ...                                              ...       ...  ...
# 19782  us/or/rockawaybeach/215spacificst/-1035432852  45.61126  ...
# 19783      us/ma/eastsandwich/669route6a/-1480952475  41.72939  ...
# 19784   us/id/coeurd'alene/702wapplewayave/210547670  47.69993  ...
# 19785      us/tn/jackson/2295nhighlandave/1759289930  35.66639  ...
# 19786      us/ak/anchorage/3811minnesotadr/806029870  61.18531  ...
#
#                                         reviews.dateSeen reviews.rating  \
# 0              2018-01-02T00:00:00Z,2017-12-17T00:00:00Z            5.0
# 1      2016-04-05T00:00:00Z,2016-06-20T00:00:00Z,2016...            5.0
# 2                                   2016-05-12T00:00:00Z            2.0
# 3                                   2017-07-14T00:00:00Z            4.0
# 4      2016-05-07T00:00:00Z,2016-07-17T00:00:00Z,2016...            3.0
# ...                                                  ...            ...
# 19782                               2016-03-23T00:00:00Z            3.0
# 19783          2016-05-13T00:00:00Z,2016-03-21T00:00:00Z            4.0
# 19784                               2017-12-17T00:00:00Z            4.0
# 19785                               2016-07-16T00:00:00Z            1.0
# 19786                               2017-12-17T00:00:00Z            1.0
#
#                                       reviews.sourceURLs  \
# 0      https://www.tripadvisor.com/Hotel_Review-g4880...
# 1      https://www.tripadvisor.com/Hotel_Review-g5340...
# 2      https://www.tripadvisor.com/Hotel_Review-g5040...
# 3      http://tripadvisor.com/Hotel_Review-g50406-d75...
# 4      https://www.tripadvisor.com/Hotel_Review-g2978...
# ...                                                  ...
# 19782  http://www.tripadvisor.com/Hotel_Review-g52043...
# 19783  https://www.tripadvisor.com/Hotel_Review-g4154...
# 19784  https://www.tripadvisor.com/Hotel_Review-g3541...
# 19785  https://www.tripadvisor.com/Hotel_Review-g5512...
# 19786  https://www.tripadvisor.com/Hotel_Review-g6088...
#
#                                             reviews.text  \
# 0      Quaint and peaceful. The Inn is perfectly nest...
# 1      My wife and I went here for a day visit and en...
# 2      So, this hotel reminded me of a motel 6. Rooms...
# 3      Checked in after 11 pm - Checked out before 11...
# 4      I feel *so* guilty giving this place a ho-hum ...
# ...                                                  ...
# 19782  It is hard for me to review an oceanfront hote...
# 19783  I live close by, and needed to stay somewhere ...
# 19784  Rolled in 11:30 laid out heads down woke up to...
# 19785  Absolutely terrible..I was told I was being gi...
# 19786  Filthy, outdated, noisy neighbours, but this w...
#
#                                 reviews.title     reviews.userCity  \
# 0                                Relaxing !!!              Warwick
# 1                            A good day visit         West Chester
# 2             Rooms are entered from outside!              Ravenna
# 3                           Great Night Sleep            Royal Oak
# 4      I FEEL SOOOO. . . GUILTY WRITING THIS!              Buffalo
# ...                                       ...                  ...
# 19782              Picture Window Ocean View!             Wildwood
# 19783            Clean, comfortable and quiet        East Sandwich
# 19784                         Passing through              Montana
# 19785                                Terrible             woodbury
# 19786                                   Polde  Sempeter pri Gorici
#
#        reviews.userProvince     reviews.username  \
# 0                   NewYork                Jen H
# 1                        PA          Steve112975
# 2                        OH     Traveler19841966
# 3                  Michigan              Terry P
# 4                        NY  Cross-Culture-Maven
# ...                     ...                  ...
# 19782                    GA             LASH0211
# 19783                    MA             Gennaker
# 19784          UnitedStates             Amber406
# 19785                   NaN          donWoodbury
# 19786              Slovenia           janezr2013
#
#                                               sourceURLs  \
# 0      http://tripadvisor.com/Hotel_Review-g48804-d16...
# 1      https://www.tripadvisor.com/Hotel_Review-g5340...
# 2      http://tripadvisor.com/Hotel_Review-g50406-d75...
# 3      http://tripadvisor.com/Hotel_Review-g50406-d75...
# 4      http://www.citysearch.com/profile/7589159/alba...
# ...                                                  ...
# 19782  https://www.tripadvisor.com/Hotel_Review-g5204...
# 19783  https://www.tripadvisor.com/Hotel_Review-g4154...
# 19784  https://www.tripadvisor.com/Hotel_Review-g3541...
# 19785  https://www.tripadvisor.com/Hotel_Review-g5512...
# 19786  https://www.tripadvisor.com/Hotel_Review-g6088...
#
#                                                 websites
# 0                        http://www.sleepyvalleyinn.com/
# 1                                  http://sunnyrest.com/
# 2      https://www.bestwestern.com/en_US/book/hotel-r...
# 3      https://www.bestwestern.com/en_US/book/hotel-r...
# 4                         http://statestreetmansion.com/
# ...                                                  ...
# 19782                   http://www.oregonsilversands.com
# 19783                           http://www.sandyneck.com
# 19784                           http://www.shiloinns.com
# 19785  http://api.citygridmedia.com/content/places/v2...
# 19786                        http://royalsuitealaska.com
#
# [19787 rows x 25 columns]

# %%
# Function to filter hotels by city
def filter_hotels_by_city(city):
    return hotel_reviews_df[hotel_reviews_df['city'].str.lower() == city.lower()]

# Function to recommend top hotels
def recommend_top_hotels(city, top_n=5):
    city_hotels = filter_hotels_by_city(city)
    top_hotels = city_hotels.groupby('name')['reviews.rating'].mean().sort_values(ascending=False).head(top_n)
    return top_hotels

# Function for sentiment analysis
def analyze_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0.5:
        return 'Better'
    elif analysis.sentiment.polarity > 0:
        return 'Good'
    else:
        return 'Neutral or Negative'

# Function to categorize reviews of a hotel
def categorize_reviews(hotel_name):
    hotel_reviews = hotel_reviews_df[hotel_reviews_df['name'].str.contains(hotel_name, case=False, na=False)]['reviews.text']
    sentiment_analysis = hotel_reviews.apply(analyze_sentiment)
    return sentiment_analysis.value_counts()

# Example usage
city_name = input("Enter the city name: ")
top_hotels = recommend_top_hotels(city_name)
print("Top 5 Hotels in", city_name)
print(top_hotels)

# %%
hotel_name = input("Enter the hotel name: ")
print("Sentiment analysis of reviews for", hotel_name)
sentiment_counts = categorize_reviews(hotel_name)
print(sentiment_counts)
# Out:
# Sentiment analysis of reviews for Sunshine
# reviews.text
# Good      9
# Better    1
# Name: count, dtype: int64
