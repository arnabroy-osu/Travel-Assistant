# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

# %% [markdown]
# # Model and API Key

# %%
# Load environment variables.
load_dotenv()

# Set the model name for our LLMs.
OPENAI_MODEL = "text-embedding-3-small"
# Store the API key in a variable.
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY)
# Out:
# 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

# %% [markdown]
# # Documents

# %%
# Additional imports for loading PDF documents and QA chain.
from langchain.document_loaders import PyPDFLoader
from langchain.chains.question_answering import load_qa_chain

# %%
# Get all documents from resources
list_pdfs = [each_file for each_file in os.listdir("Resources") if each_file.endswith(".pdf")]
list_pdfs
# Out:
# ['USA.pdf', 'Travel Guide Western USA 2024 by Authentik USA.pdf']

# %%
# Create the PDF loader and load the document.
documents = []
##for each_pdf in list_pdfs: 
pdf_loader = PyPDFLoader('Resources/Travel Guide Western USA 2024 by Authentik USA.pdf')
documents.extend(pdf_loader.load())
documents
# Out:
# [Document(page_content='© Shutterstock - 1140644786TRAVEL GUIDE\nWesternUSA\nTOP 5 ROAD TRIPS IN\nWESTERN USA P.09\nThe best tours to discover in Western USA  —\nGUIDE TO 31 MUST SEE \nDESTINATIONS P.13\nWhat to do\nWhere to eat\nTourist maps —\nPRACTICAL INFORMATION P.217\nHow to protect yourself from mosquitoes\nSouvenirs to bring back  \nDriving in the U.S.\nDriving with an automatic transmission\nTravelling by motorhome', metadata={'source': 'Resources/Travel Guide Western USA 2024 by Authentik USA.pdf', 'page': 0}),
#  Document(page_content='-\nTravel Guide \nwritten by locals.\nAuthentik USA is a local travel agency specializing in the organization of road trips \nfor families and couples.\nwww.AuthentikUSA.com', metadata={'source': 'Resources/Travel Guide Western USA 2024 by Authentik USA.pdf', 'page': 1}),
# ...

# %%
# Initialize the model.
llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name=OPENAI_MODEL, temperature=0.0)

# Create the QA chain using the LLM.
chain = load_qa_chain(llm)

# Define a query as a string.
query = 'what is FANEUIL HALL MARKETPLACE'

# Pass the documents and the query to the chain, and print the result.
result = chain.invoke({"input_documents": documents, "question": query})
print(result["output_text"])
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[13], line 11
#       8 query = 'what is FANEUIL HALL MARKETPLACE'
#      10 # Pass the documents and the query to the chain, and print the result.
# ---> 11 result = chain.invoke({"input_documents": documents, "question": query})
#      12 print(result["output_text"])
#
# File /Applications/anaconda3/envs/dev/lib/python3.10/site-packages/langchain/chains/base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File /Applications/anaconda3/envs/dev/lib/python3.10/site-packages/langchain/chains/base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# ...
